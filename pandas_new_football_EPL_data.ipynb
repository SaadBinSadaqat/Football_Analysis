# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/dataset - 2020-09-24.csv')
dfdata = df.copy()

# %%
df.head(10)
# Out:
#                 Name  Jersey Number               Club    Position  \
# 0      Sergio Aguero           10.0    Manchester-City     Forward
# 1         Harry Kane           10.0  Tottenham-Hotspur     Forward
# 2        Jamie Vardy            9.0     Leicester-City     Forward
# 3    Raheem Sterling            7.0    Manchester-City     Forward
# 4         Sadio Mané           10.0          Liverpool     Forward
# 5     Olivier Giroud           18.0            Chelsea     Forward
# 6      Mohamed Salah           11.0          Liverpool     Forward
# 7       Theo Walcott           11.0            Everton     Forward
# 8  Christian Benteke           17.0     Crystal-Palace     Forward
# 9   Gylfi Sigurdsson           10.0            Everton  Midfielder
#
#   Nationality   Age  Appearances  Wins  Losses  Goals  ...  Punches  \
# 0   Argentina  32.0          263   177      44    180  ...      NaN
# 1     England  27.0          212   120      48    144  ...      NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571 entries, 0 to 570
# Data columns (total 59 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Name                    571 non-null    object
#  1   Jersey Number           563 non-null    float64
#  2   Club                    571 non-null    object
#  3   Position                571 non-null    object
#  4   Nationality             570 non-null    object
#  5   Age                     570 non-null    float64
#  6   Appearances             571 non-null    int64
#  7   Wins                    571 non-null    int64
#  8   Losses                  571 non-null    int64
#  9   Goals                   571 non-null    int64
#  10  Goals per match         309 non-null    float64
#  11  Headed goals            502 non-null    float64
#  12  Goals with right foot   502 non-null    float64
#  13  Goals with left foot    502 non-null    float64
# ...

# %%
df
# Out:
#                  Name  Jersey Number                     Club    Position  \
# 0       Sergio Aguero           10.0          Manchester-City     Forward
# 1          Harry Kane           10.0        Tottenham-Hotspur     Forward
# 2         Jamie Vardy            9.0           Leicester-City     Forward
# 3     Raheem Sterling            7.0          Manchester-City     Forward
# 4          Sadio Mané           10.0                Liverpool     Forward
# ..                ...            ...                      ...         ...
# 566    Ki-Jana Hoever            2.0  Wolverhampton-Wanderers    Defender
# 567           Vitinha           20.0  Wolverhampton-Wanderers  Midfielder
# 568   Meritan Shabani           57.0  Wolverhampton-Wanderers  Midfielder
# 569       Fábio Silva           17.0  Wolverhampton-Wanderers     Forward
# 570  Leonardo Campana           30.0  Wolverhampton-Wanderers     Forward
#
#      Nationality   Age  Appearances  Wins  Losses  Goals  ...  Punches  \
# ...

# %%
df.isna()
# Out:
#       Name  Jersey Number   Club  Position  Nationality    Age  Appearances  \
# 0    False          False  False     False        False  False        False
# 1    False          False  False     False        False  False        False
# 2    False          False  False     False        False  False        False
# 3    False          False  False     False        False  False        False
# 4    False          False  False     False        False  False        False
# ..     ...            ...    ...       ...          ...    ...          ...
# 566  False          False  False     False        False  False        False
# 567  False          False  False     False        False  False        False
# 568  False          False  False     False        False  False        False
# 569  False          False  False     False        False  False        False
# 570  False          False  False     False        False  False        False
#
# ...

# %%
df.describe()
# Out:
#        Jersey Number         Age  Appearances        Wins      Losses  \
# count     563.000000  570.000000   571.000000  571.000000  571.000000
# mean       19.534636   25.789474    68.823117   28.957968   23.896673
# std        14.273515    4.377354    81.797516   38.969376   28.488376
# min         1.000000   17.000000     0.000000    0.000000    0.000000
# 25%         8.000000   22.000000     3.000000    1.000000    1.000000
# 50%        18.000000   26.000000    36.000000   12.000000   14.000000
# 75%        27.000000   29.000000   108.000000   41.000000   36.000000
# max        82.000000   38.000000   539.000000  272.000000  158.000000
#
#             Goals  Goals per match  Headed goals  Goals with right foot  \
# count  571.000000       309.000000    502.000000             502.000000
# mean     7.327496         2.648414      1.414343               4.468127
# std     16.810490         8.002117      3.433374              11.048341
# ...

# %%
df
# Out:
#                  Name  Jersey Number                     Club    Position  \
# 0       Sergio Aguero           10.0          Manchester-City     Forward
# 1          Harry Kane           10.0        Tottenham-Hotspur     Forward
# 2         Jamie Vardy            9.0           Leicester-City     Forward
# 3     Raheem Sterling            7.0          Manchester-City     Forward
# 4          Sadio Mané           10.0                Liverpool     Forward
# ..                ...            ...                      ...         ...
# 566    Ki-Jana Hoever            2.0  Wolverhampton-Wanderers    Defender
# 567           Vitinha           20.0  Wolverhampton-Wanderers  Midfielder
# 568   Meritan Shabani           57.0  Wolverhampton-Wanderers  Midfielder
# 569       Fábio Silva           17.0  Wolverhampton-Wanderers     Forward
# 570  Leonardo Campana           30.0  Wolverhampton-Wanderers     Forward
#
#      Nationality   Age  Appearances  Wins  Losses  Goals  ...  Punches  \
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571 entries, 0 to 570
# Data columns (total 59 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Name                    571 non-null    object
#  1   Jersey Number           563 non-null    float64
#  2   Club                    571 non-null    object
#  3   Position                571 non-null    object
#  4   Nationality             570 non-null    object
#  5   Age                     570 non-null    float64
#  6   Appearances             571 non-null    int64
#  7   Wins                    571 non-null    int64
#  8   Losses                  571 non-null    int64
#  9   Goals                   571 non-null    int64
#  10  Goals per match         309 non-null    float64
#  11  Headed goals            502 non-null    float64
#  12  Goals with right foot   502 non-null    float64
#  13  Goals with left foot    502 non-null    float64
# ...

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 566    False
# 567    False
# 568    False
# 569    False
# 570    False
# Length: 571, dtype: bool

# %%
df.loc[0]
# Out:
# Name                        Sergio Aguero
# Jersey Number                        10.0
# Club                      Manchester-City
# Position                          Forward
# Nationality                     Argentina
# Age                                  32.0
# Appearances                           263
# Wins                                  177
# Losses                                 44
# Goals                                 180
# Goals per match                      0.68
# Headed goals                         18.0
# Goals with right foot               127.0
# Goals with left foot                 34.0
# Penalties scored                     26.0
# Freekicks scored                      0.0
# Shots                               996.0
# Shots on target                     411.0
# Shooting accuracy %                   41%
# Hit woodwork                         34.0
# Big chances missed                  126.0
# Clean sheets                          NaN
# ...

# %%
df.shape
# Out:
# (571, 59)

# %%
df.head()
# Out:
#               Name  Jersey Number               Club Position Nationality  \
# 0    Sergio Aguero           10.0    Manchester-City  Forward   Argentina
# 1       Harry Kane           10.0  Tottenham-Hotspur  Forward     England
# 2      Jamie Vardy            9.0     Leicester-City  Forward     England
# 3  Raheem Sterling            7.0    Manchester-City  Forward     England
# 4       Sadio Mané           10.0          Liverpool  Forward     Senegal
#
#     Age  Appearances  Wins  Losses  Goals  ...  Punches  High Claims  Catches  \
# 0  32.0          263   177      44    180  ...      NaN          NaN      NaN
# 1  27.0          212   120      48    144  ...      NaN          NaN      NaN
# 2  33.0          213    86      77    105  ...      NaN          NaN      NaN
# 3  25.0          260   161      55     86  ...      NaN          NaN      NaN
# 4  28.0          196   121      35     86  ...      NaN          NaN      NaN
#
# ...

# %%
df.tail(10)
# Out:
#                   Name  Jersey Number                     Club    Position  \
# 561        Conor Coady           16.0  Wolverhampton-Wanderers    Defender
# 562      Rúben Vinagre           29.0  Wolverhampton-Wanderers    Defender
# 563  Maximilian Kilman           49.0  Wolverhampton-Wanderers    Defender
# 564         Oskar Buur           59.0  Wolverhampton-Wanderers    Defender
# 565             Marçal            5.0  Wolverhampton-Wanderers    Defender
# 566     Ki-Jana Hoever            2.0  Wolverhampton-Wanderers    Defender
# 567            Vitinha           20.0  Wolverhampton-Wanderers  Midfielder
# 568    Meritan Shabani           57.0  Wolverhampton-Wanderers  Midfielder
# 569        Fábio Silva           17.0  Wolverhampton-Wanderers     Forward
# 570   Leonardo Campana           30.0  Wolverhampton-Wanderers     Forward
#
#      Nationality   Age  Appearances  Wins  Losses  Goals  ...  Punches  \
# ...

# %%
df.dtypes
# Out:
# Name                       object
# Jersey Number             float64
# Club                       object
# Position                   object
# Nationality                object
# Age                       float64
# Appearances                 int64
# Wins                        int64
# Losses                      int64
# Goals                       int64
# Goals per match           float64
# Headed goals              float64
# Goals with right foot     float64
# Goals with left foot      float64
# Penalties scored          float64
# Freekicks scored          float64
# Shots                     float64
# Shots on target           float64
# Shooting accuracy %        object
# Hit woodwork              float64
# Big chances missed        float64
# Clean sheets              float64
# Goals conceded            float64
# Tackles                   float64
# Tackle success %           object
# Last man tackles          float64
# Blocked shots             float64
# ...

# %%
df.describe()
# Out:
#        Jersey Number         Age  Appearances        Wins      Losses  \
# count     563.000000  570.000000   571.000000  571.000000  571.000000
# mean       19.534636   25.789474    68.823117   28.957968   23.896673
# std        14.273515    4.377354    81.797516   38.969376   28.488376
# min         1.000000   17.000000     0.000000    0.000000    0.000000
# 25%         8.000000   22.000000     3.000000    1.000000    1.000000
# 50%        18.000000   26.000000    36.000000   12.000000   14.000000
# 75%        27.000000   29.000000   108.000000   41.000000   36.000000
# max        82.000000   38.000000   539.000000  272.000000  158.000000
#
#             Goals  Goals per match  Headed goals  Goals with right foot  \
# count  571.000000       309.000000    502.000000             502.000000
# mean     7.327496         2.648414      1.414343               4.468127
# std     16.810490         8.002117      3.433374              11.048341
# ...

# %%
df.describe(include=["O"])
# Out:
#                  Name       Club    Position Nationality Shooting accuracy %  \
# count             571        571         571         570                 309
# unique            571         20           4          57                  50
# top     Sergio Aguero  Liverpool  Midfielder     England                  0%
# freq                1         34         198         221                  44
#
#        Tackle success % Cross accuracy %
# count               390              390
# unique               54               44
# top                  0%               0%
# freq                 67               87

# %%
df.describe(include='all')
# Out:
#                  Name  Jersey Number       Club    Position Nationality  \
# count             571     563.000000        571         571         570
# unique            571            NaN         20           4          57
# top     Sergio Aguero            NaN  Liverpool  Midfielder     England
# freq                1            NaN         34         198         221
# mean              NaN      19.534636        NaN         NaN         NaN
# std               NaN      14.273515        NaN         NaN         NaN
# min               NaN       1.000000        NaN         NaN         NaN
# 25%               NaN       8.000000        NaN         NaN         NaN
# 50%               NaN      18.000000        NaN         NaN         NaN
# 75%               NaN      27.000000        NaN         NaN         NaN
# max               NaN      82.000000        NaN         NaN         NaN
#
#                Age  Appearances        Wins      Losses       Goals  ...  \
# ...

# %%
df.isnull().sum()
# Out:
# Name                        0
# Jersey Number               8
# Club                        0
# Position                    0
# Nationality                 1
# Age                         1
# Appearances                 0
# Wins                        0
# Losses                      0
# Goals                       0
# Goals per match           262
# Headed goals               69
# Goals with right foot      69
# Goals with left foot       69
# Penalties scored          262
# Freekicks scored          262
# Shots                     262
# Shots on target           262
# Shooting accuracy %       262
# Hit woodwork               69
# Big chances missed        262
# Clean sheets              309
# Goals conceded            309
# Tackles                    69
# Tackle success %          181
# Last man tackles          378
# Blocked shots              69
# Interceptions              69
# Clearances                 69
# Headed Clearance           69
# Clearances off line       378
# ...

# %%
##Exploration##

# %%
#Top 5 clubs by the number of goals scored:

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

top_5_clubs = df.groupby('Club')['Goals'].sum().nlargest(5)

top_5_clubs

top_5_clubs.plot(kind='bar')
plt.title('Top 5 Clubs by Goals Scored')
plt.xlabel('Club')
plt.ylabel('Goals')

plt.show()

# %%
top_10_scorers = df.nlargest(10, 'Goals')
plt.figure(figsize=(10, 6))
plt.bar(top_10_scorers['Name'], top_10_scorers['Goals'], color='skyblue')
plt.title('Top 10 Goal Scorers')
plt.xlabel('Player Name')
plt.ylabel('Goals')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
top_10_assist_players = df.nlargest(10, 'Assists')

plt.figure(figsize=(10, 6))
plt.bar(top_10_assist_players['Name'], top_10_assist_players['Assists'], color='lightgreen')
plt.title('Top 10 Players with Most Assists')
plt.xlabel('Player Name')
plt.ylabel('Assists')
plt.xticks(rotation=90, ha='right')
plt.tight_layout()
plt.show()

# %%
df['Goal Contributions'] = df['Goals'] + df['Assists']
top_5_contributors = df.nlargest(5, 'Goal Contributions')

plt.figure(figsize=(10, 6))
bars = plt.bar(top_5_contributors['Name'], top_5_contributors['Goal Contributions'], color='orange')
plt.title('Top 5 Players with Most Goal Contributions')
plt.xlabel('Player Name')
plt.ylabel('Goal Contributions')
plt.xticks(rotation=45, ha='right')

for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), va='bottom')

plt.tight_layout()
plt.show()

print(top_5_contributors[['Name', 'Goal Contributions']])
# Out:
#                Name  Goal Contributions
# 0     Sergio Aguero                 226
# 1        Harry Kane                 168
# 13     James Milner                 139
# 2       Jamie Vardy                 134
# 3   Raheem Sterling                 131

# %%
# Calculate the total number of goals scored with left and right foot
left_foot_goals = df['Goals with left foot'].sum()
right_foot_goals = df['Goals with right foot'].sum()

# Create a bar chart to visualize the distribution of goals scored by players' dominant foot
plt.figure(figsize=(8, 6))
bars = plt.bar(['Left Foot', 'Right Foot'], [left_foot_goals, right_foot_goals], color=['skyblue', 'salmon'])
plt.title('Distribution of Goals by Dominant Foot')
plt.xlabel('Dominant Foot')
plt.ylabel('Number of Goals')
plt.xticks(rotation=45)

# Add labels on each bar
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval), va='bottom')

plt.tight_layout()
plt.show()

print("Left Foot Goals:", left_foot_goals)
print("Right Foot Goals:", right_foot_goals)
# Out:
# Left Foot Goals: 1199.0
# Right Foot Goals: 2243.0

# %%
# Filter out players who have scored penalties
penalty_scorers = df[df['Penalties scored'] > 0]

# Sort the penalty scorers by the number of penalties scored in descending order
top_penalty_scorers = penalty_scorers.sort_values(by='Penalties scored', ascending=False).head(10)

# Create a bar plot to visualize the top penalty scorers
plt.figure(figsize=(10, 6))
sns.barplot(x='Penalties scored', y='Name', data=top_penalty_scorers, hue='Name', palette='viridis', legend=False)
plt.title('Top Penalty Scorers')
plt.xlabel('Number of Penalties Scored')
plt.ylabel('Player Name')
plt.tight_layout()
plt.show()

# %%
cards_df = df[['Name', 'Red cards', 'Yellow cards']]
cards_df = cards_df.groupby('Name').sum().reset_index()

# Sort the DataFrame by the total number of cards received in descending order
cards_df['Total cards'] = cards_df['Red cards'] + cards_df['Yellow cards']
cards_df = cards_df.sort_values(by='Total cards', ascending=False).head(10)

# Melt the DataFrame to combine red and yellow cards into a single column
cards_df_melted = pd.melt(cards_df, id_vars='Name', value_vars=['Red cards', 'Yellow cards'], var_name='Card Type', value_name='Number of Cards')

# Create a bar plot to visualize the players with the most red and yellow cards
plt.figure(figsize=(10, 6))
sns.barplot(y='Number of Cards', x='Name', hue='Card Type', data=cards_df_melted, palette='muted')
plt.title('Players with Most Red and Yellow Cards')
plt.ylabel('Number of Cards')
plt.xlabel('Player Name')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame containing the football data

# Filter out goalkeepers with penalties saved
goalkeepers_with_penalties_saved = df[df['Penalties saved'].notnull()]

# Sort the goalkeepers by the number of penalties saved in descending order and get the top 5
top_5_goalkeepers = goalkeepers_with_penalties_saved.nlargest(5, 'Penalties saved')

# Create a bar plot to visualize the top 5 goalkeepers with the most penalties saved
plt.figure(figsize=(10, 6))
sns.barplot(x='Penalties saved', y='Name', data=top_5_goalkeepers, palette='Blues_d')
plt.title('Top 5 Goalkeepers with Most Penalties Saved')
plt.xlabel('Number of Penalties Saved')
plt.ylabel('Goalkeeper Name')
plt.tight_layout()
plt.show()

print("Top 5 Goalkeepers with Most Penalties Saved:")
print(top_5_goalkeepers[['Name', 'Penalties saved']])
# Out:
# <ipython-input-65-53395776aab6>:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Penalties saved', y='Name', data=top_5_goalkeepers, palette='Blues_d')
# Top 5 Goalkeepers with Most Penalties Saved:
#                   Name  Penalties saved
# 363           Joe Hart              7.0
# 337   Lukasz Fabianski              6.0
# 464  Kasper Schmeichel              5.0
# 471             Adrián              5.0
# 522        Hugo Lloris              5.0

# %%
total_goals_by_team = df.groupby('Club')['Goals'].sum().reset_index()
total_goals_by_team = total_goals_by_team.sort_values(by='Goals', ascending=False).head(5)

# Calculate total goals scored from penalties by each team
goals_from_penalties_by_team = df.groupby('Club')['Penalties scored'].sum().reset_index()
goals_from_penalties_by_team = goals_from_penalties_by_team.sort_values(by='Penalties scored', ascending=False).head(5)

# Create a bar plot to visualize the total goals scored for each of the top 5 teams
plt.figure(figsize=(12, 6))
sns.barplot(x='Goals', y='Club', data=total_goals_by_team, color='skyblue')
plt.xlabel('Total Goals')
plt.ylabel('Team')
plt.title('Top 5 Teams with Most Goals Scored')
plt.tight_layout()
plt.show()

# Create a bar plot to visualize the goals scored from penalties for each of the top 5 teams
plt.figure(figsize=(12, 6))
sns.barplot(x='Penalties scored', y='Club', data=goals_from_penalties_by_team, color='salmon')
plt.xlabel('Goals from Penalties')
plt.ylabel('Team')
plt.title('Top 5 Teams with Most Goals Scored from Penalties')
plt.tight_layout()
plt.show()

# %%
df['Shooting accuracy %'] = df['Shooting accuracy %'].str.rstrip('%').astype(float)

# Plot the distribution of shooting accuracy percentage
plt.figure(figsize=(10, 6))
sns.histplot(df['Shooting accuracy %'].dropna(), kde=True, color='skyblue')
plt.title('Distribution of Shooting Accuracy Percentage')
plt.xlabel('Shooting Accuracy Percentage')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()df['Score'] = (
    df['Goals'] * weights['Goals'] +
    df['Assists'] * weights['Assists'] +
    df['Passes'] * weights['Passes'] +
    df['Big chances created'] * weights['Big chances created'] +
    df['Accurate long balls'] * weights['Accurate long balls'] +
    df['Through balls'] * weights['Through balls']
)

# Filter out midfield players
midfield_players = df[df['Position'] == 'Midfield']

# Sort midfield players by score in descending order and get the top 3
top_3_midfield_players = midfield_players.nlargest(3, 'Score')

print("Best 3 Midfield Players:")
print(top_3_midfield_players[['Name', 'Score']])
# Out:
# Best 3 Midfield Players:
# Empty DataFrame
# Columns: [Name, Score]
# Index: []

# %%
# Calculate win percentage for each club
df['Win Percentage'] = df['Wins'] / (df['Wins'] + df['Losses']) * 100

# Group by club and calculate the mean win percentage
club_win_percentages = df.groupby('Club')['Win Percentage'].mean().reset_index()

# Sort clubs by win percentage in descending order and get the top 5
top_5_clubs = club_win_percentages.nlargest(5, 'Win Percentage')

# Create a bar plot to visualize the top 5 clubs with the best win percentages
plt.figure(figsize=(10, 6))
sns.barplot(x='Win Percentage', y='Club', data=top_5_clubs, palette='magma', hue='Club', legend=False)
plt.title('Top 5 Clubs with the Best Win Percentages')
plt.xlabel('Win Percentage')
plt.ylabel('Club')
plt.tight_layout()

plt.show()

# %%
# Count the number of goal scorers from each nation
goal_scorers_by_nation = df.groupby('Nationality')['Name'].nunique().reset_index()
goal_scorers_by_nation.columns = ['Nationality', 'Goal Scorers Count']

# Identify the top 3 nations with the most goal scorers
top_3_nations = goal_scorers_by_nation.nlargest(3, 'Goal Scorers Count')

# Create a bar plot to visualize the top 3 nations with the most goal scorers
plt.figure(figsize=(10, 6))
sns.barplot(x='Nationality', y='Goal Scorers Count', data=top_3_nations, hue='Nationality', legend=False)
plt.title('Top 3 Nations with Most Goal Scorers')
plt.xlabel('Nationality')
plt.ylabel('Number of Goal Scorers')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Find the player who has committed the most fouls
most_fouls_player = df.loc[df['Fouls'].idxmax()]

# Print the player who has committed the most fouls
print("Player with the Most Fouls:")
print(most_fouls_player[['Name', 'Fouls']])

# Get the top 3 players with the most fouls
top_3_fouls_players = df.nlargest(3, 'Fouls')

# Create a bar plot to visualize the top 3 players with the most fouls
plt.figure(figsize=(10, 6))
sns.barplot(x='Name', y='Fouls', data=top_3_fouls_players, palette='pastel')
plt.title('Top 3 Players with the Most Fouls')
plt.xlabel('Player Name')
plt.ylabel('Number of Fouls')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# Player with the Most Fouls:
# Name     James Milner
# Fouls             438
# Name: 13, dtype: object
# <ipython-input-83-a916edfc5836>:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Name', y='Fouls', data=top_3_fouls_players, palette='pastel')

# %%
import pandas as pd

# Assuming 'df' is your DataFrame containing the football data

# Calculate the ratio of goals to shots taken for each player
df['Goals to Shots Ratio'] = df['Goals'] / df['Shots']

# Sort players by the ratio of goals to shots taken in descending order and get the top 4
top_4_players = df.nlargest(4, 'Goals to Shots Ratio')

# Display the top 4 players with the best ratio of goals to shots taken
print("Top 4 Players with the Best Ratio of Goals to Shots Taken:")
print(top_4_players[['Name', 'Goals', 'Shots', 'Goals to Shots Ratio']])
# Out:
# Top 4 Players with the Best Ratio of Goals to Shots Taken:
#                   Name  Goals  Shots  Goals to Shots Ratio
# 251      Mateusz Klich      2    2.0                   1.0
# 311  Donny van de Beek      1    1.0                   1.0
# 313       Henri Saivet      1    1.0                   1.0
# 257  Matthew Longstaff      2    4.0                   0.5

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate the total number of times each team hits the woodwork
woodwork_hits_by_team = df.groupby('Club')['Hit woodwork'].sum().reset_index()

# Sort teams by the total number of hits on the woodwork in descending order
woodwork_hits_by_team = woodwork_hits_by_team.sort_values(by='Hit woodwork', ascending=False)

# Create a bar plot to visualize the teams with the most hits on the woodwork
plt.figure(figsize=(10, 6))
sns.barplot(x='Club', y='Hit woodwork', data=woodwork_hits_by_team, hue='Club', legend=False, palette='rocket')
plt.title('Teams with the Most Hits on the Woodwork')
plt.xlabel('Team')
plt.ylabel('Number of Hits on the Woodwork')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Tackles', y='Interceptions', data=df)
plt.title('Relationship between Tackles and Interceptions')
plt.xlabel('Tackles')
plt.ylabel('Interceptions')
plt.tight_layout()
plt.show()

# %%
team_stats = df.groupby('Club').agg({'Penalties scored': 'sum', 'Wins': 'sum'}).reset_index()

# Create a scatter plot to visualize the relationship between penalties scored and matches won for each team
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Penalties scored', y='Wins', data=team_stats)
plt.title('Relationship between Penalties Scored and Matches Won (Team-wise)')
plt.xlabel('Total Penalties Scored')
plt.ylabel('Total Matches Won')
plt.tight_layout()
plt.show()

# %%
df['Shooting accuracy %'] = df['Shooting accuracy %'].str.rstrip('%').astype(float)

# Plot the distribution of shooting accuracy percentage
plt.figure(figsize=(10, 6))
sns.histplot(df['Shooting accuracy %'].dropna(), kde=True, color='skyblue')
plt.title('Distribution of Shooting Accuracy Percentage')
plt.xlabel('Shooting Accuracy Percentage')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Crosses', y='Assists', data=df)
plt.title('Relationship between Assists and Crosses')
plt.xlabel('Crosses')
plt.ylabel('Assists')
plt.tight_layout()
plt.show()

# %%
correlation = df['Goals'].corr(df['Tackles'])

# Print the correlation coefficient
print("Correlation between Goals and Tackles:", correlation)
# Out:
# Correlation between Goals and Tackles: 0.3105754665112845

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Interceptions', y='Duels won', data=df)
plt.title('Relationship between Duels Won and Interceptions')
plt.xlabel('Interceptions')
plt.ylabel('Duels Won')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Passes per match'], kde=True, color='salmon')
plt.title('Distribution of Passes per Match')
plt.xlabel('Passes per Match')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %%
top_3_freekick_specialists = df.nlargest(3, 'Freekicks scored')

# Create a bar plot to visualize the top 3 free-kick specialists
plt.figure(figsize=(10, 6))
sns.barplot(x='Freekicks scored', y='Name', data=top_3_freekick_specialists, palette='muted')
plt.title('Top 3 Free-kick Specialists')
plt.xlabel('Number of Free-kick Goals')
plt.ylabel('Player Name')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-99-d985e843297f>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Freekicks scored', y='Name', data=top_3_freekick_specialists, palette='muted')

# %%
top_3_own_goal_scorers = df.nlargest(3, 'Own goals')

# Create a bar plot to visualize the top 3 players with the most own goals
plt.figure(figsize=(10, 6))
sns.barplot(x='Own goals', y='Name', data=top_3_own_goal_scorers, palette='pastel')
plt.title('Top 3 Players with Most Own Goals')
plt.xlabel('Number of Own Goals')
plt.ylabel('Player Name')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-100-b7d6627a91a0>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Own goals', y='Name', data=top_3_own_goal_scorers, palette='pastel')

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/dataset - 2020-09-24.csv')

country_counts = df['Nationality'].value_counts()

# Select the top 5 countries with the most representation
top_5_countries = country_counts.head(5)

# Plot the data using a pie chart
plt.figure(figsize=(8, 8))
plt.pie(top_5_countries, labels=top_5_countries.index, autopct='%1.1f%%', startangle=140)
plt.title('Top 5 Countries with Most Representation in the League')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
import pandas as pd
import plotly.express as px

position_counts = df.groupby(['Nationality', 'Position']).size().reset_index(name='Count')
position_counts_pivot = position_counts.pivot(index='Nationality', columns='Position', values='Count').fillna(0)
position_counts_pivot['Total'] = position_counts_pivot.sum(axis=1)

sunburst_data = pd.DataFrame({
    'Position': ['Total'] * len(position_counts_pivot.index),
    'Nationality': position_counts_pivot.index,
    'Count': position_counts_pivot['Total']
})

# Ensure 'sunburst_data' has the same structure as 'df'
sunburst_data = sunburst_data.reindex(columns=df.columns)

concatenated_df = pd.concat([df, sunburst_data])

# Filter out non-leaf rows
leaf_rows = concatenated_df[concatenated_df['Nationality'].notna()]

fig = px.sunburst(leaf_rows,
                  path=['Position', 'Nationality'],
                  values='Appearances'
                 )

fig.update_layout(
    title='<b>Players position by country</b>',
    title_x=0.5,
    titlefont=dict(color='black', size=28, family="Courier New, monospace"),
    width=600,
    height=600,
    showlegend=False
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import matplotlib.pyplot as plt

# Group the data by club and calculate the average shots on target and total goals
team_stats = df.groupby('Club').agg({'Shots on target': 'mean', 'Goals': 'sum'}).reset_index()

# Plotting the trend line
plt.figure(figsize=(12, 6))
plt.plot(team_stats['Shots on target'], team_stats['Goals'], marker='o', linestyle='-')
plt.title('Relationship between Shots on Target and Goals')
plt.xlabel('Average Shots on Target')
plt.ylabel('Total Goals')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Group the data by club and calculate the average shots on target and total goals
team_stats = df.groupby('Club').agg({'Shots on target': 'mean', 'Goals': 'sum'}).reset_index()

# Plotting the scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(team_stats['Shots on target'], team_stats['Goals'], alpha=0.5, c='blue')
plt.title('Relationship between Shots on Target and Goals')
plt.xlabel('Average Shots on Target')
plt.ylabel('Total Goals')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd



df['Defensive Score'] = df['Tackles'] + df['Interceptions'] + df['Blocked shots'] + df['Clearances']
top_defenders = df.nlargest(4, 'Defensive Score')[['Name', 'Position', 'Tackles', 'Interceptions', 'Blocked shots', 'Clearances', 'Defensive Score']]
df['Midfielder Score'] = df['Assists'] + df['Passes'] + df['Through balls']
top_midfielders = df.nlargest(3, 'Midfielder Score')[['Name', 'Position', 'Assists', 'Passes', 'Through balls', 'Midfielder Score']]
df['Attacker Score'] = df['Goals'] + df['Assists']
top_attackers = df.nlargest(3, 'Attacker Score')[['Name', 'Position', 'Goals', 'Assists', 'Attacker Score']]

print("\n\nBest Attackers considering Goals and Assists:\n\n")
print(top_attackers)
print(top_midfielders)
print(top_defenders)
# Out:
# Best Attackers considering Goals and Assists:
#
#
#              Name    Position  Goals  Assists  Attacker Score
# 0   Sergio Aguero     Forward    180       46             226
# 1      Harry Kane     Forward    144       24             168
# 13   James Milner  Midfielder     55       84             139
#                 Name    Position  Assists  Passes  Through balls  \
# 39  Jordan Henderson  Midfielder       46   17932          129.0
# 20        Mark Noble  Midfielder       35   17862          105.0
# 13      James Milner  Midfielder       84   16171          110.0
#
#     Midfielder Score
# 39           18107.0
# 20           18002.0
# 13           16365.0
#              Name  Position  Tackles  Interceptions  Blocked shots  \
# 69  Phil Jagielka  Defender    703.0          618.0           39.0
# 42    Gary Cahill  Defender    471.0          452.0           63.0
# 91  James Tomkins  Defender    447.0          443.0           26.0
# ...
